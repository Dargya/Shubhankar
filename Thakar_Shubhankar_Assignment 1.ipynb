# %% [markdown]
# # Assignment 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1)	Load in the appropriate csv file as a pandas dataframe (batting.csv)

# %%
bat= pd.read_csv('D://MSBA//Prog for DS//Assignment 1//Batting.csv')

# %% [markdown]
# # 2)	Print out the dimensions and info about the dataframe you just created

# %%
bat.shape
# Out:
# (102816, 25)

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102816 entries, 0 to 102815
# Data columns (total 25 columns):
# playerID     102816 non-null object
# nameFirst    102816 non-null object
# nameLast     102816 non-null object
# birthYear    102816 non-null int64
# yearID       102816 non-null int64
# stint        102816 non-null int64
# teamID       102816 non-null object
# lgID         102079 non-null object
# G            102816 non-null int64
# AB           102816 non-null int64
# R            102816 non-null int64
# H            102816 non-null int64
# 2B           102816 non-null int64
# 3B           102816 non-null int64
# HR           102816 non-null int64
# RBI          102392 non-null float64
# SB           101516 non-null float64
# CS           79360 non-null float64
# BB           102816 non-null int64
# SO           94978 non-null float64
# IBB          66251 non-null float64
# HBP          100006 non-null float64
# SH           96478 non-null float64
# ...

# %%
bat.describe()
# Out:
#            birthYear         yearID          stint              G  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean     1932.991869    1964.262313       1.077838      51.343439
# std        87.105524      38.856297       0.284366      47.121658
# min         0.000000    1871.000000       1.000000       1.000000
# 25%      1905.000000    1934.000000       1.000000      13.000000
# 50%      1945.000000    1973.000000       1.000000      34.000000
# 75%      1969.000000    1998.000000       1.000000      80.000000
# max      1996.000000    2016.000000       5.000000     165.000000
#
#                   AB              R              H             2B  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean      141.905511      18.815544      37.139930       6.289167
# std       184.654492      28.242983      52.603757       9.662468
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
bat.describe(include = ['O'])
# Out:
#          playerID nameFirst nameLast  teamID    lgID
# count      102816    102816   102816  102816  102079
# unique      18915      2333     9751     149       6
# top     mcguide01      Mike    Smith     CHN      NL
# freq           31      2570      754    4863   52134

# %% [markdown]
# # 3)	How many players have hit 40 or more HRs in one single season? (Number only)

# %%
bat[bat['HR']>=40].groupby(['yearID','playerID']).sum().reset_index()['playerID'].nunique()
# Out:
# 142

# %% [markdown]
# # 4)	How many players have hit more than 600 HRs for their career? (Dataframe)

# %%
bat4 = bat.groupby('playerID').sum()
bat4[bat4['HR']>600]
# Out:
#            birthYear  yearID  stint     G     AB     R     H   2B   3B   HR  \
# playerID
# aaronha01      44482   45195     23  3298  12364  2174  3771  624   98  755
# bondsba01      43208   43923     22  2986   9847  2227  2935  601   77  762
# griffke02      45287   45997     24  2671   9801  1662  2781  524   38  630
# mayswi01       44413   45145     24  2992  10881  2062  3283  523  140  660
# rodrial01      43450   44101     22  2784  10566  2021  3115  548   31  696
# ruthba01       41690   42339     22  2503   8398  2174  2873  506  136  714
# sosasa01       37392   37945     20  2354   8813  1475  2408  379   45  609
# thomeji01      49250   50065     28  2543   8422  1583  2328  451   26  612
#
#               RBI     SB     CS    BB      SO    IBB    HBP     SH     SF  \
# playerID
# aaronha01  2297.0  240.0   73.0  1402  1383.0  293.0   32.0   21.0  121.0
# bondsba01  1996.0  514.0  141.0  2558  1539.0  688.0  106.0    4.0   91.0
# ...

# %% [markdown]
# # 5)	How many players have hit 40 2Bs, 10 3Bs, 200 Hits, and 30 HRs (inclusive) in one season? (Number Only)

# %%
bat5 = bat[['2B','3B','H','HR','yearID','playerID']].groupby(['yearID','playerID']).sum()

# %%
bat5 = bat5[(bat5['HR']>=30) & (bat5['2B']>=40) & (bat5['3B']>=10) & (bat5['H']>=200) ]

# %%
bat5.reset_index()['playerID'].nunique()
# Out:
# 11

# %% [markdown]
# # 6)	How many players have had 100 or more SBs in a season? (Dataframe)

# %%
bat6 = bat.groupby(['playerID','yearID']).sum()

# %%
bat6[(bat6['SB']>=100) ]
# Out:
#                   birthYear  stint    G   AB    R    H  2B  3B  HR    RBI  \
# playerID  yearID
# brocklo01 1974         1939      1  153  635  105  194  25   7   3   48.0
# brownpe01 1887         1861      1  134  547  137  220  35  16   4  118.0
# brownto01 1891         1860      1  137  589  177  189  30  21   5   72.0
# colemvi01 1985         1961      1  151  636  107  170  20  10   1   40.0
#           1986         1961      1  154  600   94  139  13   8   0   29.0
#           1987         1961      1  151  623  121  180  14  10   3   43.0
# comisch01 1887         1859      1  125  538  139  180  22   5   4  103.0
# fogarji01 1887         1864      1  126  495  113  129  26  12   8   50.0
# hamilbi01 1889         1866      1  137  534  144  161  17  12   3   77.0
#           1890         1866      1  123  496  133  161  13   9   2   49.0
#           1891         1866      1  133  527  141  179  23   7   2   60.0
# ...

# %% [markdown]
# # 7)	How many players in the 1960s have hit more than 200 HRs? (Dataframe)

# %%
bat7 = bat[(bat['yearID']>=1960) & (bat['yearID']<1970) ]

# %%
bat7 = bat7[['playerID','HR']]

# %%
bat7 = bat7.groupby('playerID').sum()

# %%
bat7[bat7['HR']>200]
# Out:
#             HR
# playerID
# aaronha01  375
# allisbo01  225
# bankser01  269
# cashno01   278
# cepedor01  254
# colavro01  245
# howarfr01  288
# kalinal01  210
# killeha01  393
# mantlmi01  256
# marisro01  217
# matheed01  213
# mayswi01   350
# mccovwi01  300
# powelbo01  202
# robinfr02  316
# santoro01  253
# willibi01  249
# yastrca01  202

# %% [markdown]
# # 8)	Who has hit the most HRs in history? (Dataframe)

# %%
bat8 = bat[['playerID','HR']]

# %%
bat8 = bat8.groupby('playerID').sum().sort_values('HR',ascending=False)

# %%
bat8.reset_index().sort_values('HR',ascending = False).head()
# Out:
#     playerID   HR
# 0  bondsba01  762
# 1  aaronha01  755
# 2   ruthba01  714
# 3  rodrial01  696
# 4   mayswi01  660

# %% [markdown]
# # 9)	Who had the most hits in the 1970s? (Dataframe)

# %%
bat9 = bat[(bat['yearID']>1970) & (bat['yearID']<1980)]

# %%
bat9 = bat9.groupby('playerID').sum().sort_values('H',ascending=False)

# %%
bat9[['H']].head()
# Out:
#               H
# playerID
# rosepe01   1840
# carewro01  1717
# oliveal01  1537
# garrra01   1519
# simmote01  1481

# %% [markdown]
# # 10)	Top 5 highest OBP (on base percentage) with at least 500 PAs in 1977?  (Dataframe)

# %%
bat10 = bat[bat['yearID']==1977]

# %%
bat10 = bat10.groupby(['playerID','yearID']).sum()

# %%
bat10['OBP'] = (bat10['H']  + bat10['BB'] + bat10['HBP'])/(bat10['AB'] + bat10['BB'] +bat10['HBP'] + bat10['SF'])

# %%
bat10['PA'] = (bat10['AB'] + bat10['BB'] +bat10['HBP'] + bat10['SF'] + bat10['SH'])

# %%
bat10 = bat10[bat10['PA']>=500].sort_values('OBP',ascending = False)

# %%
bat10[['OBP','PA']].head()
# Out:
#                        OBP     PA
# playerID  yearID
# carewro01 1977    0.448773  694.0
# singlke01 1977    0.437788  651.0
# smithre06 1977    0.426910  603.0
# hargrmi01 1977    0.420312  648.0
# morgajo02 1977    0.417054  645.0

# %% [markdown]
# # 11)	Top 8 highest averages in 2013 with at least 300 PAs? (Dataframe)

# %%
bat11 = bat[bat['yearID']==2013]

# %%
bat11 = bat11.groupby(['playerID','yearID']).sum()

# %%
bat11['PA'] = (bat11['AB'] + bat11['BB'] +bat11['HBP'] + bat11['SF'] + bat11['SH'])

# %%
bat11['average'] = (bat11['H']/bat11['AB'])

# %%
bat11 = bat11[bat11['PA']>=300].sort_values('average',ascending = False)

# %%
bat11.head(8)
# Out:
#                   birthYear  stint    G   AB    R    H  2B  3B  HR    RBI  \
# playerID  yearID
# cabremi01 2013         1983      1  148  555  103  193  26   1  44  137.0
# ramirha01 2013         1983      1   86  304   62  105  25   2  20   57.0
# cuddymi01 2013         1979      1  130  489   74  162  31   3  20   84.0
# mauerjo01 2013         1983      1  113  445   62  144  35   0  11   47.0
# troutmi01 2013         1991      1  157  589  109  190  39   9  27   97.0
# johnsch05 2013         1984      1  142  514   54  165  34   0  12   68.0
# freemfr01 2013         1989      1  147  551   89  176  27   2  23  109.0
# puigya01  2013         1990      1  104  382   66  122  21   2  19   42.0
#
#                     ...      CS   BB     SO   IBB   HBP   SH   SF  GIDP  \
# playerID  yearID    ...
# cabremi01 2013      ...     0.0   90   94.0  19.0   5.0  0.0  2.0  19.0
# ramirha01 2013      ...     2.0   27   52.0   3.0   3.0  0.0  2.0   5.0
# ...

# %% [markdown]
# # 12)	Leaders in hits from 1940 up to and including 1949. (Dataframe)

# %%
bat12 = bat[['H','playerID','yearID']]

# %%
bat12 = bat12[(bat12['yearID']>=1940) & (bat['yearID']<1950)]

# %%
bat12['yearID'] = bat12['yearID'].apply(str)

# %%
bat12 = bat12.groupby('playerID').sum().sort_values('H',ascending = False)

# %%
bat12.head()
# Out:
#               H
# playerID
# boudrlo01  1578
# elliobo01  1563
# walkedi02  1512
# musiast01  1432
# doerrbo01  1407

# %% [markdown]
# # 13)	Who led MLB with the most hits the most times?  And how many times?  (Dataframe, Number)

# %%
bat13 = bat[['H','playerID','yearID']]

# %%
bat13 = bat13.groupby(['yearID','playerID']).sum()

# %%
bat13 = bat13.reset_index()

# %%
bat13 = bat13.groupby(['yearID']).max()

# %%
bat13.apply(pd.value_counts).head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
#            playerID   H
# zimmech01      18.0 NaN
# zuberbi01      11.0 NaN
# ziskri01       11.0 NaN
# zuvelpa01       9.0 NaN
# yorkto01        8.0 NaN

# %%
bat13[bat13['playerID']=='zimmech01']
# Out:
#          playerID    H
# yearID
# 1884    zimmech01  185
# 1886    zimmech01  193
# 1887    zimmech01  225
# 1889    zimmech01  205
# 1890    zimmech01  197
# 1891    zimmech01  189
# 1892    zimmech01  197
# 1893    zimmech01  222
# 1894    zimmech01  237
# 1895    zimmech01  225
# 1896    zimmech01  240
# 1897    zimmech01  239
# 1898    zimmech01  216
# 1899    zimmech01  238
# 1900    zimmech01  204
# 1901    zimmech01  232
# 1902    zimmech01  193
# 1903    zimmech01  209

# %% [markdown]
# # 14) Which players have played the most games for their careers?  Top 5, descending by games played presented as a dataframe

# %%
bat14 = bat[['playerID','G']]

# %%
bat14.groupby('playerID').sum().sort_values('G', ascending = False).head()
# Out:
#               G
# playerID
# rosepe01   3562
# yastrca01  3308
# aaronha01  3298
# henderi01  3081
# cobbty01   3035

# %% [markdown]
# # 15) How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here

# %%
bat15 = bat[['H','HR','playerID']]

# %%
bat15 = bat15.groupby('playerID').sum()

# %%
bat15 = bat15[(bat15['H']>3000) & (bat15['HR']>=500)]

# %%
bat15.reset_index()['playerID'].nunique()
# Out:
# 5

# %% [markdown]
# # 16) How many HRs were hit during the entire 1988 season?  Just a number is okay here

# %%
bat16 = bat[bat['yearID']==1988]

# %%
bat16['HR'].sum()
# Out:
# 3180

# %% [markdown]
# # 17) Please filter out and show me the top 3 average seasons by Wade Boggs during his career in seasons in which he had at least 500 ABs.  I would like a dataframe sorted by average.

# %%
bat17 = bat[(bat['nameFirst']=='Wade') & (bat['nameLast']=='Boggs')]

# %%
bat17 = bat17.groupby(['playerID','yearID']).sum()

# %%
bat17['average'] = (bat17['H']/bat17['AB'])

# %%
bat17 = bat17[['average','AB']]

# %%
bat17[bat17['AB']>=500].reset_index().sort_values('average',ascending = False).reset_index().drop('index',1).head(3)
# Out:
#     playerID  yearID   average   AB
# 0  boggswa01    1985  0.367534  653
# 1  boggswa01    1988  0.366438  584
# 2  boggswa01    1987  0.362976  551

# %% [markdown]
# # 18) Please filter out the top OBPs for the 1995 season with at least 400 PAs, sorted by OBP.  I would like a dataframe for this

# %%
bat18 = bat[bat['yearID']==1995]

# %%
bat18 = bat18.groupby(['playerID','yearID']).sum()

# %%
bat18['OBP'] = (bat18['H']  + bat18['BB'] + bat18['HBP'])/(bat18['AB'] + bat18['BB'] +bat18['HBP'] + bat18['SF'])

# %%
bat18['PA'] = (bat18['AB'] + bat18['BB'] +bat18['HBP'] + bat18['SF'] + bat18['SH'])

# %%
bat18 = bat18[bat18['PA']>=400].sort_values('OBP',ascending = False)

# %%
bat18[['OBP','PA']].head()
# Out:
#                        OBP     PA
# playerID  yearID
# martied01 1995    0.478873  639.0
# thomafr04 1995    0.454405  647.0
# mcgwima01 1995    0.440758  422.0
# thomeji01 1995    0.438061  557.0
# bondsba01 1995    0.431496  635.0

# %% [markdown]
# # 19) Who had the most 3Bs (in total) in 1922, 1925, 1926, and 1928?  I would like a dataframe with just the leader

# %%
bat19 = bat[(bat['yearID']==1922) | (bat['yearID']==1925) | (bat['yearID']==1926) | (bat['yearID']==1928)]

# %%
bat19 = bat19.groupby(['yearID','playerID']).sum()

# %%
bat19 = bat19.reset_index()

# %%
bat19 = bat19.groupby(['yearID']).max().reset_index()[['yearID','playerID','3B']]

# %%
bat19
# Out:
#    yearID   playerID  3B
# 0    1922   zinnji01  22
# 1    1925  zitzmbi01  26
# 2    1926  zitzmbi01  22
# 3    1928  zitzmbi01  21

# %% [markdown]
# # 20) How many players have hit 30 or more HRs in season while also stealing (SB) 30 more or bases?  A number is okay here

# %%
bat20 = bat[['playerID','yearID','HR','SB']]

# %%
bat20 = bat20.groupby(['playerID','yearID']).sum()

# %%
bat20[(bat20['HR']>=30) & (bat20['SB']>=30)].reset_index()['playerID'].nunique()
# Out:
# 38

# %% [markdown]
# # 21) Who had the highest OBP is 1986 with at least 400 PAs? (Dataframe)

# %%
bat21 = bat[bat['yearID']==1986]

# %%
bat21 = bat21.groupby(['playerID','yearID']).sum()

# %%
bat21['OBP'] = (bat21['H']  + bat21['BB'] + bat21['HBP'])/(bat21['AB'] + bat21['BB'] +bat21['HBP'] + bat21['SF'])

# %%
bat21['PA'] = (bat21['AB'] + bat21['BB'] +bat21['HBP'] + bat21['SF'] + bat21['SH'])

# %%
bat21 = bat21[bat21['PA']>=400].sort_values('OBP',ascending = False).reset_index()

# %%
bat21[['playerID','yearID','OBP','PA']].head(1)
# Out:
#     playerID  yearID      OBP     PA
# 0  boggswa01    1986  0.45283  693.0

# %% [markdown]
# # 22) Same question but for 1997 and only in the NL (check league ID)? (Dataframe)

# %%
bat22 = bat[(bat['yearID']==1997) & (bat['lgID'] == 'NL')]

# %%
bat22 = bat22.groupby(['playerID','yearID','lgID']).sum()

# %%
bat22['OBP'] = (bat22['H']  + bat22['BB'] + bat22['HBP'])/(bat22['AB'] + bat22['BB'] +bat22['HBP'] + bat22['SF'])

# %%
bat22['PA'] = (bat22['AB'] + bat22['BB'] +bat22['HBP'] + bat22['SF'] + bat22['SH'])

# %%
bat22 = bat22[bat22['PA']>=400].sort_values('OBP',ascending = False).reset_index()

# %%
bat22[['playerID','yearID','OBP','PA','lgID']].head(1)
# Out:
#     playerID  yearID       OBP     PA lgID
# 0  walkela01    1997  0.451807  664.0   NL

# %% [markdown]
# # 23) Who had more than the league average HRs in 2012 (filter out all players with less 500 PAs)? (Dataframe)

# %%
bat23 = bat[bat['yearID'] == 2012]

# %%
bat231 = bat23.groupby(['playerID','yearID']).sum()
bat231['PA'] = (bat231['AB'] + bat231['BB'] +bat231['HBP'] + bat231['SF'] + bat231['SH'])

# %%
averageHR = bat23.groupby(['yearID']).mean()['HR']

# %%
averageHR
# Out:
# yearID
# 2012    3.504261
# Name: HR, dtype: float64

# %%
bat231[(bat231['HR'] > averageHR[2012]) & (bat231['PA'] >= 500)]
# Out:
#                   birthYear  stint    G   AB    R    H  2B  3B  HR    RBI  \
# playerID  yearID
# ackledu01 2012         1988      1  153  607   84  137  22   2  12   50.0
# alonsyo01 2012         1987      1  155  549   47  150  39   0   9   62.0
# altuvjo01 2012         1990      1  147  576   80  167  34   4   7   37.0
# alvarpe01 2012         1987      1  149  525   64  128  25   1  30   85.0
# aokino01  2012         1982      1  151  520   81  150  37   4  10   50.0
# avilemi01 2012         1981      1  136  512   57  128  28   0  13   60.0
# aybarer01 2012         1984      1  141  517   67  150  31   5   8   45.0
# barneda01 2012         1985      1  156  548   73  139  26   4   7   44.0
# beckhgo01 2012         1986      1  151  525   62  123  24   0  16   60.0
# beltrad01 2012         1979      1  156  604   95  194  33   2  36  102.0
# beltrca01 2012         1977      1  151  547   83  147  26   1  32   97.0
# ...

# %% [markdown]
# # 24) Who is the youngest player to hit 50 or more HRs in a single season? (Dataframe)

# %%
bat24 = bat[bat['HR']>=50].groupby(['yearID','playerID']).sum().reset_index()[['playerID','yearID','birthYear','HR']]

# %%
bat24 = bat24.groupby(['playerID','birthYear']).min().reset_index()

# %%
bat24['youngest'] = bat24['yearID'] - bat24['birthYear']

# %%
bat24.sort_values('youngest',ascending = True).head(1)
# Out:
#     playerID  birthYear  yearID  HR  youngest
# 6  fieldpr01       1984    2007  50        23

# %% [markdown]
# # 25) Who are the five youngest players to hit 300 or more HRs for their career? (Dataframe)

# %%
bat25 = bat.groupby(['playerID','birthYear']).sum()

# %%
bat25 = bat25[bat25['HR']>=300].sort_values('stint',ascending=True)

# %%
bat25.head()
# Out:
#                      yearID  stint     G    AB    R     H   2B  3B   HR  \
# playerID  birthYear
# kinerra01 1922        21458     12  1472  5205  971  1451  216  39  369
# vaughmo01 1967        23960     12  1512  5532  861  1620  270  10  328
# fieldpr01 1984        24126     12  1611  5821  862  1645  321  10  319
# belleal01 1966        23934     12  1539  5853  974  1726  389  21  381
# howarry01 1979        26130     13  1572  5707  848  1475  277  21  382
#
#                         RBI    SB    CS    BB      SO    IBB    HBP   SH  \
# playerID  birthYear
# kinerra01 1922       1015.0  22.0   2.0  1011   749.0    1.0   24.0  9.0
# vaughmo01 1967       1064.0  30.0  18.0   725  1429.0  144.0  108.0  0.0
# fieldpr01 1984       1028.0  18.0  11.0   847  1155.0  164.0  124.0  0.0
# belleal01 1966       1239.0  88.0  41.0   683   961.0   91.0   55.0  4.0
# howarry01 1979       1194.0  12.0   5.0   709  1843.0  154.0   59.0  0.0
#
#                        SF   GIDP
# ...

# %% [markdown]
# #  Graph total HRs per season using bar graph

# %%
cf.go_offline()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
bat26 = bat.groupby('yearID').sum().reset_index()

# %%
bat26 = bat26[['yearID','HR']]

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.3.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
bat26.iplot(kind='bar',x='yearID',y='HR')
# Out:
# <div id="d3d92c1f-4300-4b48-ae94-b9488ef709bc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d3d92c1f-4300-4b48-ae94-b9488ef709bc", [{"type": "bar", "x": [1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979
# ...

# %% [markdown]
# # Using a line graph please graph the average HRs per AB (think about this) per season

# %%
bat27 = bat.groupby('yearID').mean().reset_index()

# %%
bat27 = bat27[['yearID','HR','AB']]

# %%
bat27['HR_per_AB'] = bat27['HR']/bat27['AB']

# %%
# %matplotlib inline

# %%
bat27.plot.line(x='yearID',y='HR_per_AB',figsize=(12,3),lw=1)

# %% [markdown]
# # Thank You!! It Was a great learning experience
